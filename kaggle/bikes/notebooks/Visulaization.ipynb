# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('../train.csv', parse_dates=['datetime'], index_col = ['datetime'])
data['hour']=pd.DatetimeIndex(data.index).hour
data['day'] = pd.DatetimeIndex(data.index).day
data['year'] = pd.DatetimeIndex(data.index).year
data['month'] = pd.DatetimeIndex(data.index).month
data['weekday'] = pd.DatetimeIndex(data.index).weekday
data2 = data[data['workingday']==1]
for (year,month), mgroup in data2.groupby(['year','month']):
    figure()
    for day , dgroup in mgroup.groupby(['day']):
        p = plt.plot(dgroup['hour'],dgroup['count'], 'o-')
        plt.legend(handles=[p])

# %%
print pd.__version__
# Out:
# 0.13.1
